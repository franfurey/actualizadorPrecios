# %%
import src.data_saving as data_saving
import importlib
import src.funciones as funciones
import concat
import src.data_processing as data_processing
import src.analysis as analysis
importlib.reload(funciones)
importlib.reload(analysis)
importlib.reload(concat)
importlib.reload(data_saving)
importlib.reload(data_processing)
from concat import concat
from src.funciones import clean_algabo, clean_furey, clean_canal, scrape_drimel, clean_upalala, clean_teddy

def clean_file(canal,filename, company):
    if company == "Algabo":
        clean_algabo(filename)
        clean_canal(canal,'algabo',mpn_value=company)
        concat('algabo')
    elif company == "Furey":
        clean_furey(filename)
        clean_canal(canal,'furey',mpn_value=company)
        concat('furey')
    elif company == 'Drimel':
        scrape_drimel(filename)
        clean_canal(canal,'drimel',mpn_value=company)
        concat('drimel')
    elif company == 'Upalala':
        clean_upalala(filename)
        clean_canal(canal,'upalala',mpn_value= company)
        concat('upalala')
    elif company == 'Teddy':
        clean_teddy(filename)
        clean_canal(canal, 'teddy', mpn_value = company)
        concat('teddy')
    else:
        raise ValueError("Company not recognized")

# %%
# ALGABO
clean_file('./data/sinProcesar/canal.csv',
           './data/sinProcesar/algabo.xlsx',
           'Algabo')
# Out:
# Archivo limpio guardado como ./data/procesados/algabo.xlsx
# Archivo limpio guardado como ./data/procesados/procesadosCanal/algabo.xlsx
#
# En general, los productos aumentaron en un nan%.
# De los 319 productos, 0 sufrieron un aumento.
#
# Total de filas en df_result: 319
# Filas con similaridad del 100%: 282
# Filas de CANAL no encontradas en df2: 17
# Filas de df2 no encontradas en CANAL: 20
#
# Archivo CONCATENADO guardado como ./data/proveedor/algabo/listos/algabo.xlsx
#
# No se encontraron aumentos excesivos en los productos.
# El archivo CSV se ha guardado en: /Users/franciscofurey/00DataScience/Canal/actualizadorPrecios/data/proveedor/algabo/listos/tiendaNube/algabo.csv

# %%
# DRIMEL
clean_file('./data/sinProcesar/canal.csv',
           ['https://drimel.com.ar/?product_cat=bebes', 'https://drimel.com.ar/?product_cat=cuidado-del-bebe'],
            'Drimel')
# Out:
# Archivo guardado con exito
# Archivo limpio guardado como ./data/procesados/procesadosCanal/drimel.xlsx
#
# En general, los productos aumentaron en un 24.67%.
# De los 248 productos, 6 sufrieron un aumento.
#
# Total de filas en df_result: 248
# Filas con similaridad del 100%: 144
# Filas de CANAL no encontradas en df2: 47
# Filas de df2 no encontradas en CANAL: 57
#
# Archivo CONCATENADO guardado como ./data/proveedor/drimel/listos/drimel.xlsx
#
# Se encontraron 4 productos con un aumento excesivo:
#   - PAMPERS SUPER XTR ULTRA Mx48 (SKU: Drimel7703) aumentó un 55.00%.
#   - Pampers - Pants Protección Continua - Mensual - XGrande - 52 Unidades (SKU: Drimel8293) aumentó un 33.00%.
#   - Babysec - Super premium - XGrande x 36 (SKU: Drimel8767) aumentó un 27.00%.
#   - Huggies - Pañal Flexi Comfort - Recién Nacidos - 17 Unidades (SKU: Drimel1081) aumentó un 25.00%.
# El archivo CSV se ha guardado en: /Users/franciscofurey/00DataScience/Canal/actualizadorPrecios/data/proveedor/drimel/listos/tiendaNube/drimel.csv

# %%
# FUREY
clean_file('./data/sinProcesar/canal.csv',
           './data/sinProcesar/furey.xlsx',
           'Furey')
# Out:
# Archivo limpio guardado como ./data/procesados/furey.xlsx
# Archivo limpio guardado como ./data/procesados/procesadosCanal/furey.xlsx
#
# En general, los productos aumentaron en un 31.32%.
# De los 2288 productos, 69 sufrieron un aumento.
#
# Total de filas en df_result: 2288
# Filas con similaridad del 100%: 1803
# Filas de CANAL no encontradas en df2: 264
# Filas de df2 no encontradas en CANAL: 221
#
# Archivo CONCATENADO guardado como ./data/proveedor/furey/listos/furey.xlsx
#
# Se encontraron 47 productos con un aumento excesivo:
#   - ALGABO COCOA BEACH PROTECTOR SOLAR F 45 x 200 ml (SKU: Furey5283) aumentó un 166.00%.
#   - ALG COCOA BEACH ACEITE BRONC C/COCO SPRAY x250 ml (SKU: Furey1335) aumentó un 162.00%.
#   - ALG COCOA BEACH ACEITE BRONC C/ZANAHORIA FP 8 SPRAY x250ml (SKU: Furey3731) aumentó un 158.00%.
#   - ALG COCOA BEACH PROTECTOR SOLAR FAMILIAR F 30 x 400 ml (SKU: Furey5839) aumentó un 157.00%.
#   - ALGABO COCOA BEACH GEL POST SOLAR POMO x 200 gr (SKU: Furey1952) aumentó un 156.00%.
#   - ALGABO COCOA BEACH PROTECTOR SOLAR F 30 x 200 ml (SKU: Furey5282) aumentó un 153.00%.
#   - ALGABO COCOA BEACH PROTECTOR SOLAR F 15 x 200 ml (SKU: Furey5281) aumentó un 153.00%.
#   - ALGABO COCOA BEACH LOCION SPRAY BRONZER FPS 8 x 250 ml (SKU: Furey5284) aumentó un 26.00%.
#   - VENDA ADHERENTE FLEX HIPOALERGIC (TIPO COBAN) 5 cm x 4,5 mts. (SKU: Furey1482) aumentó un 25.00%.
#   - HIPO APOSITO FILM 6cm x 7cm x 3 unid (SKU: Furey5861) aumentó un 25.00%.
#   - PARCHE OCULAR HIPOALERGIC PEDIATRICO x 20 u (SKU: Furey2147) aumentó un 25.00%.
#   - CINTA ADHESIVA NEUROMUSCULAR KIN HIPOALERGIC 5 cm x 5 mts ROJO BLISTER (SKU: Furey4231) aumentó un 25.00%.
#   - CINTA ADHESIVA NEUROMUSCULAR KIN HIPOALERGIC 5 cm x 5 mts NEGRO BLISTER (SKU: Furey4239) aumentó un 25.00%.
#   - CINTA ADHESIVA NEUROMUSCULAR KIN HIPOALERGIC 5 cm x 5 mts PIEL BLISTER (SKU: Furey4241) aumentó un 25.00%.
#   - CINTA ADHESIVA NEUROMUSCULAR KIN HIPOALERGIC 5 cm x 5 mts AZUL (SKU: Furey423) aumentó un 25.00%.
#   - HIPO PARCHE OCULAR PEDIATRICO x 5 u (SKU: Furey5862) aumentó un 25.00%.
#   - TELA AD. OXIDO ZINC FUREY N5 (MOD 2) x 24 r 1,25cmx4m (SKU: Furey5705) aumentó un 25.00%.
#   - HIPO VENDA FISIOPLAST (TENSOPLAST) 7,5cm x 4,5m (SKU: Furey3885) aumentó un 25.00%.
#   - VENDA ADHERENTE FLEX HIPOALERGIC (TIPO COBAN) 10 cm x 4,5 mts. (SKU: Furey1484) aumentó un 24.00%.
#   - PARCHE OCULAR HIPOALERGIC ADULTO x 20 u (SKU: Furey268) aumentó un 24.00%.
#   - CINTA ADHESIVA NEUROMUSCULAR KIN HIPOALERGIC 5 cm x
#   - PINCEL PARA TINTURA CHICO x 12 unid. (SKU: Furey11) aumentó un 18.00%.
#   - PEINE COLA GRANDE COLOR x 5 unidades (SKU: Furey1275) aumentó un 18.00%.
#   - PINCEL PARA TINTURA GRANDE x 6 unid. (SKU: Furey4879) aumentó un 17.00%.
#   - CEPILLO PARA UAS (SKU: Furey38) aumentó un 17.00%.
#   - BICARBONATO DE SODIO FUREY POTE x 100 gr (SKU: Furey4044) aumentó un 12.00%.
# El archivo CSV se ha guardado en: /Users/franciscofurey/00DataScience/Canal/actualizadorPrecios/data/proveedor/furey/listos/tiendaNube/furey.csv

# %%
# UPALALA
clean_file('./data/sinProcesar/canal.csv',
           './data/sinProcesar/upalala.xlsx',
           'Upalala')
# Out:
# Archivo limpio guardado como ./data/procesados/upalala.xlsx
# Archivo limpio guardado como ./data/procesados/procesadosCanal/upalala.xlsx
#
# En general, los productos aumentaron en un nan%.
# De los 53 productos, 0 sufrieron un aumento.
#
# Total de filas en df_result: 53
# Filas con similaridad del 100%: 29
# Filas de CANAL no encontradas en df2: 23
# Filas de df2 no encontradas en CANAL: 1
#
# Archivo CONCATENADO guardado como ./data/proveedor/upalala/listos/upalala.xlsx
#
# No se encontraron aumentos excesivos en los productos.
# El archivo CSV se ha guardado en: /Users/franciscofurey/00DataScience/Canal/actualizadorPrecios/data/proveedor/upalala/listos/tiendaNube/upalala.csv

# %%
# TEDDY
clean_file('./data/sinProcesar/canal.csv',
           './data/sinProcesar/teddy.xlsx',
           'Teddy')
# Out:
# Archivo limpio guardado como ./data/procesados/teddy.xlsx
# Imágenes eliminadas del archivo ./data/procesados/teddy.xlsx
# Archivo limpio guardado como ./data/procesados/procesadosCanal/teddy.xlsx
#
# En general, los productos aumentaron en un 22.23%.
# De los 101 productos, 73 sufrieron un aumento.
#
# Total de filas en df_result: 101
# Filas con similaridad del 100%: 95
# Filas de CANAL no encontradas en df2: 0
# Filas de df2 no encontradas en CANAL: 6
#
# Archivo CONCATENADO guardado como ./data/proveedor/teddy/listos/teddy.xlsx
#
# Se encontraron 73 productos con un aumento excesivo:
#   - Cubre cochecito (SKU: Teddy405) aumentó un 32.00%.
#   - PLATO TÉRMICO 3 DIVISIONES (SKU: Teddy415) aumentó un 29.00%.
#   - BABITAS X 2 UNIDADES (SKU: Teddy6253) aumentó un 28.00%.
#   - Taza 2 en 1 (SKU: Teddy272) aumentó un 28.00%.
#   - ASPIRADOR NASAL ERGONÓMETRO (SKU: Teddy8102) aumentó un 27.00%.
#   - ASPIRADOR NASAL ERGONÓMETRO C/ 2 PICOS (SKU: Teddy8103) aumentó un 27.00%.
#   - Mordillo refrigerante Pato Dormilon (SKU: Teddy262) aumentó un 27.00%.
#   - Mordillo refrigerante hipo equilibrista (SKU: Teddy263) aumentó un 27.00%.
#   - PLATO TÉRMICO SIN DIVISIONES (SKU: Teddy4151) aumentó un 26.00%.
#   - TOALLÓN C/CAPUCHA (SKU: Teddy6254) aumentó un 26.00%.
#   - Cuchara avioncito (SKU: Teddy506) aumentó un 26.00%.
#   - Juego de cubiertos (SKU: Teddy505) aumentó un 25.00%.
#   - Cadena porta chupete (SKU: Teddy207) aumentó un 25.00%.
#   - CAJITA SONAJERO COCHECITO FANTASÍA (SKU: Teddy5053) aumentó un 25.00%.
#   - Taza con asa y tapa (SKU: Teddy408) aumentó un 25.00%.
#   - Sonajero hipo equilibrista (SKU: Teddy1264) aumentó un 25.00%.
#   - Sonajero pato dormilon (SKU: Teddy1265) aumentó un 25.00%.
#   - PLATO+VASITO+ CUBIERTOS (SKU: Teddy425) aumentó un 24.00%.
#   - Porta chupete osito (SKU: Teddy2081) aumentó un 24.00%.
#   - Porta chupete corazon (SKU: Teddy208) aumentó un 24.00%.
#   - Mordillo refrigerante medalla fantasia (SKU: Teddy267) aumentó un 24.00%.
#   - Combo plato + vaso + cuchara avioncito (SKU: Teddy901) aumentó un 24.00%.
#   - Protector de mosquitos (SKU: Teddy406) aumentó un 23.00%.
#   - Mordillo refrigerante color (SKU: Teddy274) aumentó un 23.00%.
#   - Esponja Bebe (SKU: Teddy255) aumentó un 23.00%.
#   - Teddy - Sonajero bolita - Fluo (SKU: Teddy266) aumentó un 23.00%.
#   - Mordillo refrigerante (SKU: Teddy273) aumentó un 23.00%.
#   - Taza 3 en 1 (SKU: Teddy268) aumentó un 22.00%.
#   - BANDANA X 1 UNIDAD (SKU: Teddy6252) aumentó un 22.00%.
#   - Vaso bebe decorado (SKU: Teddy407) aumentó un 22.00%.
#   - CEPILLOS LIMPIAMAMADERA CON MANGO (SKU: Teddy261) aumentó un 22.00%.
#   - Chupete cristal con tetina de latex (SKU: Teddy282) aumentó un 21.00%.
#   - Teddy - Biberón Acinturado con Tetina - 250 ml - Latex (SKU: Teddy199) aumentó un 21.00%.
#   - Teddy - Biberón Tradicional con Tetina - 140 ml - Latex (SKU: Teddy1161) aumentó un 21.00%.
#   - Tetina tradicional de latex (SKU: Teddy229) aumentó un 21.00%.
#   - TETINA LÁTEX X 2 c/flujos (SKU: Teddy228) aumentó un 21.00%.
#   - Ajuar Chico (SKU: Teddy91) aumentó un 21.00%.
#   - Teddy - Cambiador plastico (SKU: Teddy403) aumentó un 21.00%.
#   - Chupete decorado con tetina de latex (SKU: Teddy276) aumentó un 21.00%.
#   - SONAJERO COLGANTE PARA CUNA/COCHECITO (SKU: Teddy5056) aumentó un 21.00%.
#   - Chupete decorado con tetina de silicona (SKU: Teddy281) aumentó un 21.00%.
#   - Biberon tradicional con tetina de latex 250 ml (SKU: Teddy12) aumentó un 21.00%.
#   - Combo plato + cuchara avioncito + taza (SKU: Teddy905) aumentó un 21.00%.
